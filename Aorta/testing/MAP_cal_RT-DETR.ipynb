# %%
from ultralytics import RTDETR
import numpy as np
import torch
import torchvision.ops as ops
import os

# Load your fine-tuned RT-DETR model
model = RTDETR("/mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Model/run_1_lr0.0001_sz640_mosaicTrue_wd0.0_lrf0.1/weights/best.pt")

# Path to dataset YAML file
data_yaml = "/mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/data.yaml"

# Run evaluation on validation set
results = model.val(data=data_yaml, split='val')

# Get mAP50 for individual classes
map50_per_class = results.box.maps  # mAP50 for each class

# Class names mapping (ensure matches your trained dataset)
class_names = {
    0: "ascending_aorta",
    1: "SOV",
    2: "LVOT"
}

# # Print individual mAP50 for each class
# for i, class_name in class_names.items():
#     print(f"mAP50 for {class_name}: {map50_per_class[i]:.4f}")

# # Print overall mAP50
# print(f"Overall mAP50: {results.box.map50:.4f}")

# Path to validation images and corresponding labels
val_images_dir = "/mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val"
val_labels_dir = "/mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/labels/val"

# Run inference on validation images to get predictions
pred_results = model.predict(source=val_images_dir, save=False, conf=0.001)

# Extract IoU values for bounding boxes with highest confidence per class
ious = []

# Function to load YOLO ground truth boxes from a .txt file
def load_yolo_labels(label_path, img_shape):
    boxes = []
    if os.path.exists(label_path):
        with open(label_path, "r") as f:
            lines = f.readlines()
            for line in lines:
                parts = line.strip().split()
                class_id = int(parts[0])
                x_center, y_center, w, h = map(float, parts[1:5])
                
                # Convert YOLO format (x_center, y_center, w, h) to (x1, y1, x2, y2)
                x1 = (x_center - w / 2) * img_shape[1]
                y1 = (y_center - h / 2) * img_shape[0]
                x2 = (x_center + w / 2) * img_shape[1]
                y2 = (y_center + h / 2) * img_shape[0]
                
                boxes.append((class_id, x1, y1, x2, y2))
    return boxes

# Iterate through each predicted image
for pred in pred_results:
    if pred.boxes is not None and len(pred.boxes) > 0:
        img_name = os.path.basename(pred.path).replace(".jpg", ".txt").replace(".png", ".txt")
        label_path = os.path.join(val_labels_dir, img_name)

        # Load ground truth boxes for the current image
        gt_boxes_data = load_yolo_labels(label_path, pred.orig_shape)
        
        for class_id in class_names.keys():
            # Filter predictions for the current class
            class_preds = pred.boxes[pred.boxes.cls == class_id]
            
            if len(class_preds) > 0 and len(gt_boxes_data) > 0:
                # Select the box with the highest confidence
                best_box = class_preds[np.argmax(class_preds.conf.cpu().numpy())]
                pred_box_xyxy = best_box.xyxy.cpu()

                # Filter ground truth boxes for the current class
                gt_class_boxes = [box[1:] for box in gt_boxes_data if box[0] == class_id]
                if len(gt_class_boxes) > 0:
                    gt_boxes_xyxy = torch.tensor(gt_class_boxes)

                    # Calculate IoU between best prediction and ground truth boxes
                    iou_matrix = ops.box_iou(pred_box_xyxy, gt_boxes_xyxy)
                    best_iou = iou_matrix.max().item()
                    ious.append(best_iou)

# Calculate mean IoU for highest confidence bounding boxes per class
mean_iou = np.mean(ious) if ious else 0.0
print(f"Mean IoU (bounding boxes with highest confidence per class): {mean_iou:.4f}")
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.16 torch-2.5.1 CUDA:0 (NVIDIA H100 80GB HBM3, 81090MiB)
# rt-detr-l summary: 302 layers, 31,989,905 parameters, 0 gradients, 103.4 GFLOPs
# val: Scanning /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/labels/val.cache... 59 images, 0 backgrounds, 0 corrupt: 100%|██████████| 59/59 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<00:00,  1.96it/s]
#                    all         59        177       0.85      0.836      0.848      0.263
#        ascending_aorta         59         59      0.677      0.644      0.636      0.162
#                    SOV         59         59      0.981      0.983      0.982      0.449
#                   LVOT         59         59      0.892      0.881      0.927      0.178
# Speed: 2.6ms preprocess, 15.1ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val
#
# image 1/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_314.png: 640x640 175 ascending_aortas, 8 SOVs, 117 LVOTs, 19.1ms
# image 2/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_377.png: 640x640 140 ascending_aortas, 19 SOVs, 141 LVOTs, 20.0ms
# image 3/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S B - 3mensio Screen Recording_longitudinal_view_1003.png: 640x640 102 ascending_aortas, 51 SOVs, 147 LVOTs, 20.1ms
# image 4/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S B - 3mensio Screen Recording_longitudinal_view_845.png: 640x640 134 ascending_aortas, 27 SOVs, 139 LVOTs, 19.0ms
# image 5/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S B - 3mensio Screen Recording_longitudinal_view_941.png: 640x640 126 ascending_aortas, 17 SOVs, 157 LVOTs, 19.3ms
# image 6/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S G_longitudinal_view_310.png: 640x640 110 ascending_aortas, 26 SOVs, 164 LVOTs, 19.1ms
# image 7/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S G_longitudinal_view_315.png: 640x640 106 ascending_aortas, 16 SOVs, 178 LVOTs, 21.4ms
# image 8/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S G_longitudinal_view_325.png: 640x640 104 ascending_aortas, 26 SOVs, 170 LVOTs, 19.2ms
# image 9/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S R M R - 3mensio Screen Recording_longitudinal_view_327.png: 640x640 183 ascending_aortas, 47 SOVs, 70 LVOTs, 20.9ms
# image 10/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S R M R - 3mensio Screen Recording_longitudinal_view_419.png: 640x640 175 ascending_aortas, 20 SOVs, 105 LVOTs, 20.9ms
# image 11/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S R M R - 3mensio Screen Recording_longitudinal_view_473.png: 640x640 125 ascending_aortas, 34 SOVs, 141 LVOTs, 21.5ms
# image 12/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S S_longitudinal_view_536.png: 640x640 114 ascending_aortas, 16 SOVs, 170 LVOTs, 19.7ms
# image 13/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S S_longitudinal_view_781.png: 640x640 198 ascending_aortas, 13 SOVs, 89 LVOTs, 19.5ms
# image 14/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S S_longitudinal_view_900.png: 640x640 166 ascending_aortas, 22 SOVs, 112 LVOTs, 21.6ms
# image 15/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S0319RS_longitudinal_view_408.png: 640x640 129 ascending_aortas, 44 SOVs, 127 LVOTs, 19.6ms
# image 16/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S0319RS_longitudinal_view_475.png: 640x640 166 ascending_aortas, 27 SOVs, 107 LVOTs, 20.2ms
# image 17/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S0319RS_longitudinal_view_482.png: 640x640 166 ascending_aortas, 27 SOVs, 107 LVOTs, 20.4ms
# image 18/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S0330KS_longitudinal_view_255.png: 640x640 212 ascending_aortas, 15 SOVs, 73 LVOTs, 20.0ms
# image 19/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S0330KS_longitudinal_view_284.png: 640x640 136 ascending_aortas, 27 SOVs, 137 LVOTs, 19.3ms
# image 20/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/S0330KS_longitudinal_view_331.png: 640x640 104 ascending_aortas, 34 SOVs, 162 LVOTs, 19.7ms
# image 21/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/Schuszter, József - 3mensio Screen Recording_longitudinal_view_334.png: 640x640 82 ascending_aortas, 24 SOVs, 194 LVOTs, 19.9ms
# image 22/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/Schuszter, József - 3mensio Screen Recording_longitudinal_view_338.png: 640x640 136 ascending_aortas, 18 SOVs, 146 LVOTs, 19.8ms
# image 23/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/Schuszter, József - 3mensio Screen Recording_longitudinal_view_449.png: 640x640 107 ascending_aortas, 45 SOVs, 148 LVOTs, 22.9ms
# image 24/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/TRAJKOVIÆ, MIRJANA - 3mensio Screen Recording_longitudinal_view_432.png: 640x640 191 ascending_aortas, 18 SOVs, 91 LVOTs, 20.6ms
# image 25/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/TRAJKOVIÆ, MIRJANA - 3mensio Screen Recording_longitudinal_view_561.png: 640x640 97 ascending_aortas, 36 SOVs, 167 LVOTs, 32.2ms
# image 26/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/TRAJKOVIÆ, MIRJANA - 3mensio Screen Recording_longitudinal_view_608.png: 640x640 88 ascending_aortas, 48 SOVs, 164 LVOTs, 19.7ms
# image 27/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/Tsintsadze Izolda - 3mensio Screen Recording_longitudinal_view_419.png: 640x640 90 ascending_aortas, 32 SOVs, 178 LVOTs, 19.7ms
# image 28/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/Tsintsadze Izolda - 3mensio Screen Recording_longitudinal_view_427.png: 640x640 124 ascending_aortas, 37 SOVs, 139 LVOTs, 18.8ms
# image 29/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/Tsintsadze Izolda - 3mensio Screen Recording_longitudinal_view_429.png: 640x640 116 ascending_aortas, 26 SOVs, 158 LVOTs, 20.4ms
# image 30/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/U M_longitudinal_view_447.png: 640x640 127 ascending_aortas, 11 SOVs, 162 LVOTs, 21.0ms
# image 31/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/U M_longitudinal_view_489.png: 640x640 86 ascending_aortas, 14 SOVs, 200 LVOTs, 20.6ms
# image 32/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/U M_longitudinal_view_504.png: 640x640 86 ascending_aortas, 14 SOVs, 200 LVOTs, 30.7ms
# image 33/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/U S J - 3mensio Screen Recording_longitudinal_view_753.png: 640x640 90 ascending_aortas, 7 SOVs, 203 LVOTs, 19.5ms
# image 34/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/U S J - 3mensio Screen Recording_longitudinal_view_825.png: 640x640 105 ascending_aortas, 19 SOVs, 176 LVOTs, 19.3ms
# image 35/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/U S J - 3mensio Screen Recording_longitudinal_view_845.png: 640x640 146 ascending_aortas, 21 SOVs, 133 LVOTs, 19.3ms
# image 36/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V - 3mensio Screen Recording_longitudinal_view_1080.png: 640x640 131 ascending_aortas, 22 SOVs, 147 LVOTs, 18.8ms
# image 37/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V - 3mensio Screen Recording_longitudinal_view_747.png: 640x640 101 ascending_aortas, 46 SOVs, 153 LVOTs, 20.6ms
# image 38/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V - 3mensio Screen Recording_longitudinal_view_894.png: 640x640 103 ascending_aortas, 44 SOVs, 153 LVOTs, 19.1ms
# image 39/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V A F_longitudinal_view_363.png: 640x640 139 ascending_aortas, 31 SOVs, 130 LVOTs, 19.0ms
# image 40/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V A F_longitudinal_view_409.png: 640x640 179 ascending_aortas, 27 SOVs, 94 LVOTs, 20.0ms
# image 41/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V A F_longitudinal_view_531.png: 640x640 116 ascending_aortas, 54 SOVs, 130 LVOTs, 20.1ms
# image 42/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V J - 3mensio Screen Recording_longitudinal_view_582.png: 640x640 138 ascending_aortas, 11 SOVs, 151 LVOTs, 33.6ms
# image 43/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V J - 3mensio Screen Recording_longitudinal_view_702.png: 640x640 101 ascending_aortas, 29 SOVs, 170 LVOTs, 19.5ms
# image 44/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V J - 3mensio Screen Recording_longitudinal_view_710.png: 640x640 100 ascending_aortas, 41 SOVs, 159 LVOTs, 19.4ms
# image 45/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V K - 3mensio Screen Recording_longitudinal_view_594.png: 640x640 148 ascending_aortas, 24 SOVs, 128 LVOTs, 17.2ms
# image 46/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V K - 3mensio Screen Recording_longitudinal_view_723.png: 640x640 93 ascending_aortas, 22 SOVs, 185 LVOTs, 20.7ms
# image 47/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V K - 3mensio Screen Recording_longitudinal_view_752.png: 640x640 94 ascending_aortas, 20 SOVs, 186 LVOTs, 20.1ms
# image 48/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V V - 3mensio Screen Recording_longitudinal_view_658.png: 640x640 119 ascending_aortas, 16 SOVs, 165 LVOTs, 30.0ms
# image 49/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V V - 3mensio Screen Recording_longitudinal_view_763.png: 640x640 91 ascending_aortas, 10 SOVs, 199 LVOTs, 19.9ms
# image 50/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/V V - 3mensio Screen Recording_longitudinal_view_935.png: 640x640 99 ascending_aortas, 16 SOVs, 185 LVOTs, 19.5ms
# image 51/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/Varga, Nándor - 3mensio Screen Recording_longitudinal_view_538.png: 640x640 97 ascending_aortas, 16 SOVs, 187 LVOTs, 19.2ms
# image 52/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/Varga, Nándor - 3mensio Screen Recording_longitudinal_view_688.png: 640x640 123 ascending_aortas, 13 SOVs, 164 LVOTs, 18.7ms
# image 53/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/Varga, Nándor - 3mensio Screen Recording_longitudinal_view_783.png: 640x640 92 ascending_aortas, 11 SOVs, 197 LVOTs, 18.9ms
# image 54/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/W D - 3mensio Screen Recording_longitudinal_view_1109.png: 640x640 155 ascending_aortas, 18 SOVs, 127 LVOTs, 19.2ms
# image 55/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/W D - 3mensio Screen Recording_longitudinal_view_1227.png: 640x640 146 ascending_aortas, 21 SOVs, 133 LVOTs, 19.0ms
# image 56/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/W D - 3mensio Screen Recording_longitudinal_view_799.png: 640x640 111 ascending_aortas, 18 SOVs, 171 LVOTs, 19.4ms
# image 57/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/ФИЛИППОВ, Ярослав Владимирович_longitudinal_view_417.png: 640x640 106 ascending_aortas, 46 SOVs, 148 LVOTs, 21.3ms
# image 58/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/ФИЛИППОВ, Ярослав Владимирович_longitudinal_view_456.png: 640x640 143 ascending_aortas, 20 SOVs, 137 LVOTs, 19.6ms
# image 59/59 /mnt/nvme_disk2/User_data/hp927k/cardioVision/Phase2_/Datasets/images/val/ФИЛИППОВ, Ярослав Владимирович_longitudinal_view_471.png: 640x640 186 ascending_aortas, 22 SOVs, 92 LVOTs, 19.7ms
# Speed: 2.2ms preprocess, 20.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Mean IoU (bounding boxes with highest confidence per class): 0.6139

# %%
####
