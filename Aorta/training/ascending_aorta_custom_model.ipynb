# %%
import os
import shutil
import random

original_image_folder = "/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/totalImages"
original_sov_label_folder = "/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV"
original_aorta_label_folder = "/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelAscendingAorta"

# New folders to hold the split dataset
train_image_folder = "./train_images"
test_image_folder  = "./test_images"

train_sov_label_folder = "./train_labelSOV"
test_sov_label_folder  = "./test_labelSOV"

train_aorta_label_folder = "./train_labelAorta"
test_aorta_label_folder  = "./test_labelAorta"

# Create directories if they don't exist
os.makedirs(train_image_folder, exist_ok=True)
os.makedirs(test_image_folder, exist_ok=True)

os.makedirs(train_sov_label_folder, exist_ok=True)
os.makedirs(test_sov_label_folder, exist_ok=True)

os.makedirs(train_aorta_label_folder, exist_ok=True)
os.makedirs(test_aorta_label_folder, exist_ok=True)

# Gather all images in the original folder
all_images = [
    f for f in os.listdir(original_image_folder)
    if f.lower().endswith((".jpg", ".png", ".jpeg"))
]

# 80% for train, 20% for test
split_idx = int(0.8 * len(all_images))
train_files = all_images[:split_idx]
test_files  = all_images[split_idx:]

def copy_label_if_exists(label_folder_src, label_folder_dst, base_name):
    """
    Copies the label file if it exists for the given image base name.
    E.g. label file is base_name + '.txt'.
    """
    label_file = base_name + ".txt"
    src_path = os.path.join(label_folder_src, label_file)
    if os.path.exists(src_path):
        dst_path = os.path.join(label_folder_dst, label_file)
        shutil.copy(src_path, dst_path)

# Copy training images and labels
for img_file in train_files:
    # Copy the image
    src_img = os.path.join(original_image_folder, img_file)
    dst_img = os.path.join(train_image_folder, img_file)
    shutil.copy(src_img, dst_img)

    # Also copy the SOV and Aorta label
    base_name, _ = os.path.splitext(img_file)
    copy_label_if_exists(original_sov_label_folder, train_sov_label_folder, base_name)
    copy_label_if_exists(original_aorta_label_folder, train_aorta_label_folder, base_name)

# Copy testing images and labels
for img_file in test_files:
    # Copy the image
    src_img = os.path.join(original_image_folder, img_file)
    dst_img = os.path.join(test_image_folder, img_file)
    shutil.copy(src_img, dst_img)

    # Also copy the SOV and Aorta label
    base_name, _ = os.path.splitext(img_file)
    copy_label_if_exists(original_sov_label_folder, test_sov_label_folder, base_name)
    copy_label_if_exists(original_aorta_label_folder, test_aorta_label_folder, base_name)

print("Train/Test split complete.")
print(f"Train images: {len(train_files)}")
print(f"Test images: {len(test_files)}")
# Out:
# Train/Test split complete.
# Train images: 967
# Test images: 242

# %%
import os
import numpy as np
import torch
import torch.nn.functional as F
from ultralytics import YOLO
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as T
from PIL import Image
import cv2
import torch.nn as nn

##############################################
# Define paths (adjust these as needed)
##############################################
train_image_folder = "./train_images"  # must be defined previously
test_image_folder  = "./test_images"   # must be defined previously
feature_save_train = "extracted_features_total"
feature_save_test  = "extracted_features_total"

##############################################
# Feature Extraction Code (using global average pooling)
##############################################
# This code assumes that the YOLO neck returns a tensor of shape [B, 32, 160, 160].
# Global average pooling will convert it to shape [B, 32].
yolo = YOLO("yolov8n.pt")  # or your custom .pt
yolo.model.eval()
backbone = yolo.model.model[0]
neck = yolo.model.model[1]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
backbone.to(device)
neck.to(device)
backbone.eval()
neck.eval()

class MyImagesDataset(Dataset):
    def __init__(self, image_folder, transform=None):
        self.image_folder = image_folder
        self.image_files = [f for f in os.listdir(image_folder)
                            if f.lower().endswith((".jpg", ".png", ".jpeg"))]
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path = os.path.join(self.image_folder, img_name)
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        return image, img_name

transform = T.Compose([
    T.Resize((640, 640)),
    T.ToTensor()
])

# Create datasets and loaders for feature extraction (batch_size=1 for simplicity)
train_dataset_img = MyImagesDataset(train_image_folder, transform=transform)
test_dataset_img  = MyImagesDataset(test_image_folder, transform=transform)
train_loader_img = DataLoader(train_dataset_img, batch_size=1, shuffle=False)
test_loader_img  = DataLoader(test_dataset_img, batch_size=1, shuffle=False)

def extract_neck_features(dataloader, save_dir):
    os.makedirs(save_dir, exist_ok=True)
    with torch.no_grad():
        for images, img_names in dataloader:
            images = images.to(device)
            # Run images through YOLO backbone and neck
            backbone_outputs = backbone(images)
            neck_outputs = neck(backbone_outputs)
            if isinstance(neck_outputs, list):
                feats = neck_outputs[0]  # Expected shape: [B, 32, 160, 160]
            else:
                feats = neck_outputs
            # Apply global average pooling: from [B, 32, 160, 160] to [B, 32]
            feats = F.adaptive_avg_pool2d(feats, (4, 4))
            feats = feats.view(feats.size(0), -1)
            feats = feats.cpu().numpy()
            for i, name in enumerate(img_names):
                base_name, _ = os.path.splitext(name)
                out_path = os.path.join(save_dir, base_name + ".npy")
                np.save(out_path, feats[i])
    print(f"Done! Extracted neck features saved in '{save_dir}'.")

# Run feature extraction for train and test images
extract_neck_features(train_loader_img, feature_save_train)
extract_neck_features(test_loader_img, feature_save_test)


# print(count)
import numpy as np 
test=np.load("/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/extracted_features_total/P G - 3mensio Screen Recording_longitudinal_view_242_brightness_contrast.npy")
print(test)
# Out:
# Done! Extracted neck features saved in 'extracted_features_total'.
# Done! Extracted neck features saved in 'extracted_features_total'.
# [      1.282     0.67313      0.7362     0.75269     0.62895     0.68957     0.80632     0.85958     0.60634      1.2078     0.80859      1.0512     0.51512     0.66284     0.72925      1.2712      1.6092      1.2039      1.1945      1.1908      1.0989      1.2441      1.3387      1.4315     0.79884      1.2955
#       1.3847      1.2603      1.0451      1.2707      1.2418      2.2747      2.2949      2.5207      2.6004      2.2886      2.4708      2.4347      2.5919      2.4617      2.0269      2.2646      2.5667      2.4806      2.1314      2.3822      2.6582      2.5102      1.3888     0.50115     0.45272     0.49158
#      0.44819     0.54675     0.57034     0.63219     0.35534     0.55983     0.58893     0.60479     0.48392     0.59202     0.51163      1.3459     0.87551     0.15504     0.11292     0.10387     0.15212     0.15387     0.14129     0.13978     0.10298     0.19252     0.16942     0.20167    0.081671     0.13049
#       0.1515     0.91473       1.434     0.82374     0.76475     0.72176     0.66571     0.79412     0.90984     0.97429     0.61941     0.99809     0.94198     0.97334     0.63017     0.77411     0.83643      1.1567      1.6046       1.389      1.4647      1.3565      1.0765      1.1546      1.4296      1.1442
#       1.9589      1.4462      1.4347      1.3447      1.4503      1.1613      1.5648      1.6307      2.4252      1.1212      1.0162      1.0087      1.1748      1.1374      1.2274      1.2528      1.3015      1.2278      1.2808      1.2403      1.4761      1.1887      1.2914       2.593      1.1685     0.18937
#      0.16097     0.23107     0.37517     0.25192     0.18558     0.24427     0.30403     0.25188     0.23625     0.27945     0.25316     0.23511     0.20259      1.4009       2.351      2.5031      2.3769      2.1359      2.3446      2.4206        2.35      2.2193      2.0443      2.2867      2.4145      2.2392
#       2.2074      2.3981      2.2911      2.5848      2.4823      2.8112      2.7216      2.4576      2.9181      2.8259       2.933      2.8427      2.3466      2.7398       2.863      2.8995      2.4863      2.7011      2.9407      2.9315      2.6232      2.7286      2.2883      2.1807      2.4841      2.4987
#       2.4167      2.4209      2.8796       3.118      2.5041      2.8731      2.6778        2.35      2.5528      3.6093      3.5014      2.4904      2.6547      2.9546      2.4094       2.503      2.1628      2.4999      3.1071      3.2333      2.5108       2.822      3.0846      2.7821      2.2497      3.7726
#       1.4471     0.70627     0.58947     0.68032     0.69469     0.76603     0.79596     0.89063     0.57324      0.8283     0.81247     0.79418     0.63472      0.7817     0.78098      1.3697      1.2485     0.40905     0.45579     0.37417     0.31328     0.38921       0.319     0.38211     0.37986      0.4352
#      0.41646     0.49969      0.2836     0.41456      0.4215      2.3333      3.4062      2.9722       2.375      2.5706      2.6233      3.0277      2.4946      2.4391      3.0403      2.9971      2.8263      2.6836      3.2866      3.0218       2.473      3.5215      1.8836      1.3013      1.0124      1.6264
#        1.741      1.6545     0.96785      1.5352      1.8501       1.706      1.0441      1.4623      1.8274      1.6635      1.0804      1.5783     0.70248      0.1125     0.23795      0.2255    0.028087    0.058064    0.077065    0.067072     0.34174     0.85743     0.12788      0.6625   -0.017259    0.047715
#     0.077368     0.83705      6.2795      3.0742      2.0875      4.9614      3.7859      3.9593      1.7177      3.4207      7.8876      5.5411      1.8592      3.6314      6.2292      4.4928      2.5638      4.2993       1.002     0.12238    0.077988     0.12092     0.12137     0.11565     0.11352     0.15302
#      0.23288     0.19048     0.12547     0.21823     0.20925     0.15541     0.14397     0.91089      2.5942      1.9171      1.8656      2.4342      1.8352      2.0945      2.0852      2.4482       2.045       2.265      2.2388      2.6626       2.631      1.9443      2.1419      3.5817     0.61492     0.66706
#      0.45549     0.41865     0.15327     0.19006      0.2261     0.21224     0.16249     0.20434     0.24825     0.20299     0.11784     0.17639     0.21903      1.4002      1.4751     0.79317      0.6468     0.70362     0.68061     0.81162     0.90265     0.91497     0.53138     0.82859      0.9455     0.83012
#      0.72633     0.87478      0.8472      1.3611      1.2127     0.33016     0.17946     0.27188     0.29564     0.34079     0.30065     0.34556     0.32085     0.35252     0.33647     0.41221      0.3136     0.33754     0.45388      1.1042     0.87966     0.15408     0.17921     0.17213     0.14031     0.15261
#      0.16553     0.18549     0.15266     0.23095     0.19481     0.25846     0.12494     0.15732     0.16334     0.95148      1.9852      1.6367      1.7519      1.3194      1.2093      1.2632      1.4161      1.3086      1.3356      1.4645      1.4875      1.4588      1.2505      1.2469      1.3879      2.7313
#        1.396     0.78003      0.5139      1.3187      1.0636      1.0458     0.41025     0.96903      1.7355      1.5072     0.44841      1.0551      1.5306      1.2914     0.58918      1.0328     0.76104     0.18951      0.2516     0.11273    0.067091     0.12225     0.15609     0.14805     0.29321     0.46964
#       0.1926     0.39946     0.05149    0.072138     0.14656     0.53611      3.3675      2.7675      2.8191       3.011      2.7416      2.7922      2.6428      2.7808      3.2585      3.4548      2.6995      3.1039      2.8707      2.7906      2.7067      3.9254      1.1293     0.89242     0.76401       1.115
#       1.1102      1.0693     0.68574       1.027      1.1972      1.1338     0.69784     0.96448      1.2005      1.1017     0.64946     0.90019      6.4839      6.3742      6.1507      6.5908      6.7234      6.5822      6.0967      6.5234      6.5142      6.7199      6.0581      6.5002      6.5597      6.7343
#       6.3225      6.6032       2.523      2.8726      3.0353      2.6438      2.9445      2.8549      3.0833      2.9288      2.1284      2.6969      3.0724      2.9713      2.4447      2.7964      3.0449      2.8723]

# %%
import numpy as np
t=np.load("/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/extracted_features_test/P G - 3mensio Screen Recording_longitudinal_view_242_brightness_contrast.npy")
print(t.shape)
# Out:
# (512,)

# %%
# ##############################################
# # Now define the dataset for bounding-box regression
# ##############################################
# class BBFeaturesDataset(Dataset):
#     def __init__(self, feature_dir, sov_label_dir, aorta_label_dir, expected_feat_dim):
#         self.feature_dir = feature_dir
#         self.sov_label_dir = sov_label_dir
#         self.aorta_label_dir = aorta_label_dir
#         self.expected_feat_dim = expected_feat_dim  # expected_feat_dim should be 32 + 4 = 36

#         self.feature_files = [f for f in os.listdir(feature_dir) if f.endswith(".npy")]

#     def __len__(self):
#         return len(self.feature_files)

#     def __getitem__(self, idx):
#         feature_file = self.feature_files[idx]
#         base_name = feature_file.replace(".npy", "")
        
#         # 1) Load YOLO feature (expected shape [32])
#         feat_path = os.path.join(self.feature_dir, feature_file)
#         try:
#             features = np.load(feat_path)
#         except Exception:
#             return None
#         features = torch.from_numpy(features).float()
        
#         # 2) Load SOV bounding box (assumes format: class x y w h)
#         sov_txt = os.path.join(self.sov_label_dir, base_name + ".txt")
#         try:
#             with open(sov_txt, "r") as f:
#                 line = f.readline().strip()
#                 vals = list(map(float, line.split()))
#                 sov_bbox = vals[1:]  # skip class
#         except (ValueError, FileNotFoundError):
#             return None
#         sov_bbox = torch.tensor(sov_bbox, dtype=torch.float32)
        
#         # 3) Combine features and SOV bbox -> Expected shape: [32 + 4] = [36]
#         combined_input = torch.cat([features, sov_bbox], dim=0)
#         if combined_input.shape[0] != self.expected_feat_dim:
#             return None
        
#         # 4) Load Aorta bounding box (assumes format: class x y w h)
#         aorta_txt = os.path.join(self.aorta_label_dir, base_name + ".txt")
#         try:
#             with open(aorta_txt, "r") as f:
#                 line = f.readline().strip()
#                 vals = list(map(float, line.split()))
#                 aorta_bbox = vals[1:]  # skip class
#         except (ValueError, FileNotFoundError):
#             return None
#         aorta_bbox = torch.tensor(aorta_bbox, dtype=torch.float32)
        
#         return combined_input, aorta_bbox

# def skip_invalid_collate_fn(batch):
#     valid_batch = [x for x in batch if x is not None]
#     if len(valid_batch) == 0:
#         return None
#     from torch.utils.data.dataloader import default_collate
#     return default_collate(valid_batch)

# ##############################################
# # Create the BBFeaturesDataset and split into train/test
# ##############################################
# feature_dir = feature_save_test  # or feature_save_train, depending on which split you want to test
# sov_label_dir = "/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV"
# aorta_label_dir = "/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelAscendingAorta"

# # expected_feat_dim: 32 from pooled features + 4 for the SOV bbox = 36
# expected_feat_dim = 32 + 4

# full_bb_dataset = BBFeaturesDataset(
#     feature_dir=feature_dir,
#     sov_label_dir=sov_label_dir,
#     aorta_label_dir=aorta_label_dir,
#     expected_feat_dim=expected_feat_dim
# )

# # Split into train/test
# train_size = int(0.8 * len(full_bb_dataset))
# test_size = len(full_bb_dataset) - train_size
# train_dataset, test_dataset = random_split(full_bb_dataset, [train_size, test_size],
#                                           generator=torch.Generator().manual_seed(42))

# # Create DataLoaders
# train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True, collate_fn=skip_invalid_collate_fn)
# test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=skip_invalid_collate_fn)
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split

##############################################
# Dataset for bounding-box regression with debug prints
##############################################
class BBFeaturesDataset(Dataset):
    def __init__(self, feature_dir, sov_label_dir, aorta_label_dir, expected_feat_dim):
        self.feature_dir = feature_dir
        self.sov_label_dir = sov_label_dir
        self.aorta_label_dir = aorta_label_dir
        self.expected_feat_dim = expected_feat_dim  # expected_feat_dim should be 32 + 4 = 36

        self.feature_files = [f for f in os.listdir(feature_dir) if f.endswith(".npy")]
        # print(f"[DEBUG] Found {len(self.feature_files)} feature files in {feature_dir}")

    def __len__(self):
        return len(self.feature_files)

    # Modify __getitem__ to handle invalid SOV labels
    def __getitem__(self, idx):
        feature_file = self.feature_files[idx]
        base_name = feature_file.replace(".npy", "")

        # 1) Load YOLO feature (expected shape [32])
        feat_path = os.path.join(self.feature_dir, feature_file)
        try:
            features = np.load(feat_path)
        except Exception as e:
            # print(f"[DEBUG] Error loading features for {base_name}: {e}")
            return None
        features = torch.from_numpy(features).float()
        # print(f"[DEBUG] features shape for {base_name}: {features.shape}")

        # 2) Load SOV bounding box
        sov_txt = os.path.join(self.sov_label_dir, base_name + ".txt")
        try:
            with open(sov_txt, "r") as f:
                line = f.readline().strip()
                # Ensure all parts are numeric
                if not all(part.replace('.', '', 1).isdigit() for part in line.split()):
                    # print(f"[DEBUG] Invalid SOV label for {base_name}: {line}")
                    return None
                vals = list(map(float, line.split()))
                sov_bbox = vals[1:]  # skip class
        except (ValueError, FileNotFoundError) as e:
            # print(f"[DEBUG] Error loading SOV label for {base_name}: {e}")
            return None

        sov_bbox = torch.tensor(sov_bbox, dtype=torch.float32)

        # 3) Combine features and SOV bbox -> Expected shape: [32 + 4] = [36]
        combined_input = torch.cat([features, sov_bbox], dim=0)
        # print(f"[DEBUG] Combined input shape for {base_name}: {combined_input.shape}")
        if combined_input.shape[0] != self.expected_feat_dim:
            # print(f"[DEBUG] Combined input shape {combined_input.shape[0]} does not match expected {self.expected_feat_dim} for {base_name}")
            return None

        # 4) Load Aorta bounding box (assumes format: class x y w h)
        aorta_txt = os.path.join(self.aorta_label_dir, base_name + ".txt")
        try:
            with open(aorta_txt, "r") as f:
                line = f.readline().strip()
                vals = list(map(float, line.split()))
                aorta_bbox = vals[1:]  # skip class
        except (ValueError, FileNotFoundError) as e:
            # print(f"[DEBUG] Error loading Aorta label for {base_name}: {e}")
            return None

        aorta_bbox = torch.tensor(aorta_bbox, dtype=torch.float32)

        return combined_input, aorta_bbox

# Update skip_invalid_collate_fn to filter out invalid samples
def skip_invalid_collate_fn(batch):
    valid_batch = [x for x in batch if x is not None]
    if len(valid_batch) == 0:
        # print("[DEBUG] skip_invalid_collate_fn: Batch is empty after filtering invalid samples.")
        return None
    from torch.utils.data.dataloader import default_collate
    return default_collate(valid_batch)


##############################################
# Create the BBFeaturesDataset and split into train/test
##############################################
# Update these paths as needed:
feature_dir = "extracted_features_total"  # or "extracted_features_train"
sov_label_dir = "/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV"
aorta_label_dir = "/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelAscendingAorta"

# expected_feat_dim: 32 from pooled features + 4 for the SOV bbox = 36
expected_feat_dim = 512 + 4

full_bb_dataset = BBFeaturesDataset(
    feature_dir=feature_dir,
    sov_label_dir=sov_label_dir,
    aorta_label_dir=aorta_label_dir,
    expected_feat_dim=expected_feat_dim
)

print(f"[DEBUG] Total samples in full_bb_dataset: {len(full_bb_dataset)}")

# Split into train/test
train_size = int(0.8 * len(full_bb_dataset))
test_size = len(full_bb_dataset) - train_size
train_dataset, test_dataset = random_split(full_bb_dataset, [train_size, test_size],
                                          generator=torch.Generator().manual_seed(42))

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True, collate_fn=skip_invalid_collate_fn)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=skip_invalid_collate_fn)
# Out:
# [DEBUG] Total samples in full_bb_dataset: 1209

# %%
print(train_size)
# Out:
# 967

# %%
# for i in range(5):
#     sample = full_bb_dataset[i]
#     print(i, sample)

# %%
# Debug: iterate over one batch from the train loader and print shapes
print("[DEBUG] Checking one batch from train_loader:")
count_train=0
count_test=0
for batch in train_loader:
    if batch is None:
        continue
        # print("[DEBUG] Received empty batch from train_loader.")
    else:
        count_train+=1
        inputs, targets = batch
        # print(f"[DEBUG] Train batch inputs shape: {inputs.shape}")
        # print(f"[DEBUG] Train batch targets shape: {targets.shape}")

# Debug: iterate over one batch from the test loader and print shapes
print("[DEBUG] Checking one batch from test_loader:")
for batch in test_loader:
    if batch is None:
        continue
        # print("[DEBUG] Received empty batch from test_loader.")
    else:
        count_test+=1
        inputs, targets = batch
        # print(f"[DEBUG] Test batch inputs shape: {inputs.shape}")
        # print(f"[DEBUG] Test batch targets shape: {targets.shape}")
print(count_train)
print(count_test)
# Out:
# [DEBUG] Checking one batch from train_loader:
# [DEBUG] Checking one batch from test_loader:
# 964
# 241

# %%
print(test_size)
# Out:
# 242

# %%
print(full_bb_dataset[0])
# Out:
# (tensor([ 7.1584e-02,  2.6673e-01,  3.5296e-01,  3.4407e-01,  8.4384e-02,  2.3904e-01,  2.0641e-01,  2.9894e-01,  6.6111e-01,  5.8709e-01,  1.5757e-01,  1.0350e+00,  2.7312e+00,  8.3184e-01,  2.4677e-01,  1.6019e+00,  2.8077e-01,  6.7877e-01,  5.7386e-01,  7.3079e-01,  4.1862e-01,  6.2889e-01,  4.9524e-01,  6.8352e-01,
#          5.7770e-01,  5.1273e-01,  3.9516e-01,  9.5255e-01,  2.7095e+00,  1.0394e+00,  5.0559e-01,  1.6623e+00,  1.9263e+00,  2.2489e+00,  2.3104e+00,  2.2609e+00,  2.1886e+00,  2.5274e+00,  2.5764e+00,  2.4813e+00,  2.4544e+00,  2.5613e+00,  2.5888e+00,  2.4636e+00,  3.4011e+00,  2.7121e+00,  2.2931e+00,  2.0916e+00,
#          5.7011e-01,  3.6994e-01,  3.1260e-01,  4.7662e-01,  6.6651e-01,  3.9207e-01,  3.4196e-01,  4.8202e-01,  6.5930e-01,  2.7941e-01,  2.9743e-01,  4.8515e-01,  3.5693e+00,  1.0667e+00,  2.6723e-01,  1.4673e+00,  2.5234e-02,  2.1282e-01,  3.5342e-01,  3.2693e-01,  1.2221e-01,  3.2764e-01,  3.7302e-01,  3.7246e-01,
#          2.1866e-01,  2.3942e-01,  2.3248e-01,  3.3870e-01,  2.9148e+00,  1.0806e+00,  2.6005e-01,  1.2156e+00,  3.9848e-02,  3.0812e-01,  4.0331e-01,  3.6390e-01,  8.4474e-02,  3.6337e-01,  2.9690e-01,  3.6710e-01,  2.1669e-01,  2.3913e-01,  2.3829e-01,  3.5405e-01,  2.3292e+00,  7.6011e-01,  2.9099e-01,  1.1108e+00,
#          1.6973e+00,  1.4764e+00,  1.7040e+00,  1.3041e+00,  1.2806e+00,  1.0510e+00,  1.7832e+00,  1.3708e+00,  1.2657e+00,  1.2004e+00,  1.2404e+00,  1.2734e+00,  1.4719e+00,  1.1478e+00,  1.2151e+00,  2.0416e+00,  7.0621e-01,  7.9566e-01,  8.9320e-01,  9.3231e-01,  8.0626e-01,  8.3280e-01,  9.5457e-01,  1.1021e+00,
#          9.2179e-01,  6.7476e-01,  6.6523e-01,  1.0750e+00,  3.6617e+00,  1.5316e+00,  5.3252e-01,  2.7425e+00,  6.7252e-01,  2.1991e-01,  2.6158e-01,  2.6011e-01,  6.8486e-01,  2.1805e-01,  2.2859e-01,  3.1768e-01,  5.1873e-01,  1.7405e-01,  1.7116e-01,  3.0150e-01,  3.2548e+00,  1.1330e+00,  1.4370e-01,  1.6633e+00,
#          1.8769e+00,  2.1753e+00,  2.3862e+00,  2.2200e+00,  2.2143e+00,  2.4180e+00,  2.4575e+00,  2.4320e+00,  2.2432e+00,  2.5215e+00,  2.3816e+00,  2.3104e+00,  3.1531e+00,  2.6125e+00,  2.0483e+00,  2.5179e+00,  2.1557e+00,  2.3556e+00,  2.3509e+00,  2.5481e+00,  2.5428e+00,  2.8352e+00,  2.8226e+00,  2.8335e+00,
#          2.8383e+00,  3.0570e+00,  2.9932e+00,  3.1357e+00,  3.0752e+00,  3.0263e+00,  2.7079e+00,  2.7014e+00,  2.0227e+00,  2.3989e+00,  2.6382e+00,  2.9622e+00,  2.0790e+00,  2.6728e+00,  2.4297e+00,  2.7730e+00,  2.2950e+00,  2.4848e+00,  2.5315e+00,  3.5136e+00,  3.1321e+00,  2.8665e+00,  2.8590e+00,  4.2595e+00,
#          2.8064e+00,  3.2349e+00,  3.4657e+00,  3.1741e+00,  2.6881e+00,  2.6998e+00,  2.2375e+00,  2.7193e+00,  2.7210e+00,  2.0508e+00,  1.7963e+00,  2.9267e+00,  3.2895e+00,  2.3934e+00,  2.5270e+00,  4.4953e+00,  2.5522e-01,  2.7865e-01,  2.7382e-01,  3.0177e-01,  3.0900e-01,  2.5593e-01,  2.0082e-01,  2.6199e-01,
#          2.7140e-01,  1.5848e-01,  1.3239e-01,  3.2083e-01,  2.7260e+00,  9.6620e-01,  1.5242e-01,  1.4028e+00,  3.8582e-01,  6.6785e-01,  9.6460e-01,  1.0083e+00,  5.9836e-01,  8.9305e-01,  8.3994e-01,  9.6549e-01,  7.4695e-01,  6.7695e-01,  6.4719e-01,  1.1336e+00,  3.3255e+00,  1.5315e+00,  6.7780e-01,  2.2588e+00,
#          2.5558e+00,  2.8639e+00,  3.3506e+00,  2.7697e+00,  2.8676e+00,  2.8495e+00,  2.9138e+00,  3.2011e+00,  2.5379e+00,  2.8127e+00,  2.4118e+00,  3.0277e+00,  3.3068e+00,  2.8281e+00,  2.2641e+00,  4.3874e+00,  1.9124e+00,  1.7203e+00,  1.5045e+00,  1.9166e+00,  1.8117e+00,  1.5467e+00,  9.8153e-01,  1.3528e+00,
#          1.7537e+00,  1.3431e+00,  1.2659e+00,  1.6578e+00,  1.9272e+00,  1.7786e+00,  1.8237e+00,  1.9893e+00,  4.2883e-02,  1.5056e-01,  4.1403e-01,  3.6593e-01, -1.6960e-03,  1.6686e-01,  1.8851e-01,  2.1763e-01,  7.9036e-01,  6.9611e-01,  1.0790e-01,  1.2993e+00,  2.4793e+00,  6.1238e-01,  1.7822e-01,  1.8433e+00,
#          7.8013e+00,  5.2842e+00,  3.7624e+00,  4.9708e+00,  5.8792e+00,  2.8766e+00,  6.7687e-01,  2.1838e+00,  4.9463e+00,  2.3326e+00,  1.3475e+00,  3.9401e+00,  5.3416e+00,  4.6183e+00,  5.4804e+00,  7.6984e+00, -9.7813e-03,  2.3058e-01,  3.3300e-01,  3.3381e-01,  8.7259e-02,  3.1845e-01,  3.0417e-01,  3.2309e-01,
#          2.0042e-01,  2.0597e-01,  1.9481e-01,  3.4418e-01,  2.9963e+00,  1.0792e+00,  2.5792e-01,  1.2780e+00,  1.5393e+00,  2.2254e+00,  2.0273e+00,  2.8745e+00,  1.5280e+00,  2.1256e+00,  1.9717e+00,  2.7587e+00,  1.8298e+00,  1.7790e+00,  1.8306e+00,  3.0136e+00,  3.0112e+00,  1.9906e+00,  1.9865e+00,  4.0781e+00,
#          9.2559e-02,  4.4680e-01,  4.4612e-01,  6.1741e-01,  2.5415e-02,  2.6858e-01,  3.0113e-01,  2.4745e-01,  4.0790e-01,  4.6706e-01,  1.7918e-01,  7.2913e-01,  2.2761e+00,  7.0097e-01,  1.6394e-01,  7.0152e-01,  4.9025e-02,  2.6913e-01,  2.7459e-01,  3.0820e-01,  1.3347e-01,  2.7624e-01,  2.2149e-01,  2.7371e-01,
#          1.5669e-01,  1.3770e-01,  1.1147e-01,  2.9850e-01,  2.6825e+00,  1.0335e+00,  1.6146e-01,  1.1578e+00,  9.4780e-02,  2.1740e-01,  2.4947e-01,  3.0748e-01,  2.3501e-01,  2.8496e-01,  2.7707e-01,  3.8818e-01,  2.7934e-01,  2.2541e-01,  1.6992e-01,  3.3659e-01,  3.0313e+00,  1.2839e+00,  2.0287e-01,  1.3940e+00,
#          8.0853e-02,  2.5666e-01,  3.6483e-01,  4.1737e-01,  1.7928e-01,  3.7044e-01,  3.5119e-01,  4.1097e-01,  3.8057e-01,  3.1666e-01,  2.3226e-01,  5.6768e-01,  2.6980e+00,  8.5193e-01,  3.0086e-01,  1.2174e+00,  1.1120e+00,  1.4979e+00,  1.8470e+00,  1.8003e+00,  1.1517e+00,  1.4948e+00,  1.6844e+00,  1.6052e+00,
#          1.3947e+00,  1.4941e+00,  1.4254e+00,  1.7844e+00,  3.7034e+00,  1.7493e+00,  1.2649e+00,  2.5302e+00,  1.7880e+00,  1.2800e+00,  8.8812e-01,  1.2771e+00,  1.5835e+00,  8.9697e-01,  2.5648e-01,  6.3740e-01,  1.5314e+00,  7.5324e-01,  4.7797e-01,  1.0784e+00,  1.4867e+00,  1.3766e+00,  1.3738e+00,  1.5486e+00,
#          1.5272e-02,  1.6249e-01,  4.0488e-01,  2.7970e-01,  8.6150e-03,  2.5911e-01,  2.8076e-01,  2.7319e-01,  1.2199e-01,  1.5052e-01,  2.1116e-01,  2.1760e-01,  1.6694e+00,  4.5780e-01,  2.0828e-01,  7.4104e-01,  2.9906e+00,  2.8408e+00,  2.9387e+00,  3.0454e+00,  2.7193e+00,  2.6827e+00,  2.3999e+00,  2.6366e+00,
#          2.9627e+00,  2.7151e+00,  2.4552e+00,  3.3096e+00,  3.7468e+00,  3.0098e+00,  2.9741e+00,  4.3480e+00,  1.2869e+00,  1.1251e+00,  9.2249e-01,  1.2445e+00,  1.2584e+00,  1.1188e+00,  5.5443e-01,  8.9528e-01,  1.2221e+00,  1.0481e+00,  9.6745e-01,  1.1704e+00,  1.0794e+00,  1.2271e+00,  1.3052e+00,  1.1543e+00,
#          6.4717e+00,  6.3678e+00,  5.7533e+00,  6.3073e+00,  6.6216e+00,  6.4021e+00,  5.4641e+00,  5.8847e+00,  6.8784e+00,  6.3115e+00,  5.8844e+00,  6.5467e+00,  6.9773e+00,  6.7928e+00,  6.6146e+00,  6.1997e+00,  2.0919e+00,  2.4896e+00,  2.6093e+00,  2.5937e+00,  2.5583e+00,  2.9605e+00,  3.0624e+00,  2.9863e+00,
#          2.9883e+00,  3.1744e+00,  3.0974e+00,  3.0386e+00,  2.9640e+00,  2.8347e+00,  2.4836e+00,  2.2141e+00,  4.7179e-01,  3.9063e-01,  6.9533e-01,  4.6046e-01]), tensor([0.5891, 0.3489, 0.2145, 0.0704]))

# %%
##############################################
# Determine the input dimension dynamically from one sample
##############################################
sample, _ = full_bb_dataset[0]
in_dim = sample.shape[0]  # This should be 32 (features) + len(sov_bbox) (typically 4)
print("Determined input dimension:", in_dim)

##############################################
# 8) MLP Model Definition
##############################################
class AscAortaMLP(nn.Module):
    def __init__(self, in_dim=516, hidden1=256, hidden2=16, final_hidden1=128, final_hidden2=64, out_dim=4):
        super().__init__()
        
        # Layers for the first 512 values
        self.fc1 = nn.Linear(512, hidden1)
        self.fc2 = nn.Linear(hidden1, hidden2)  # Produces a 16-dimensional vector
        self.relu = nn.ReLU()
        
        # Layers for the combined (16 + 4 = 20) vector
        self.fc3 = nn.Linear(hidden2 + 4, final_hidden1)
        self.fc4 = nn.Linear(final_hidden1, final_hidden2)
        self.fc5 = nn.Linear(final_hidden2, out_dim)

    def forward(self, x):
        """
        x: Input tensor of shape (batch_size, 516)
        """
        # Split x into two parts: the first 512 values and the last 4 values
        x1 = x[:, :512]  # Shape (batch_size, 512)
        x2 = x[:, 512:]  # Shape (batch_size, 4)
        
        # Pass x1 (512) through two layers
        x1 = self.relu(self.fc1(x1))
        x1 = self.relu(self.fc2(x1))  # Output is now 16-dimensional
        
        # Concatenate x1 (16) with x2 (4) to form a 20-dimensional vector
        combined = torch.cat([x1, x2], dim=1)
        
        # Pass the combined vector through the final layers
        x = self.relu(self.fc3(combined))
        x = self.relu(self.fc4(x))
        return self.relu(self.fc5(x))


model = AscAortaMLP(in_dim=in_dim, hidden1=512, hidden2=256, out_dim=4)
model.to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

##############################################
# 9) Training Loop
##############################################

epochs = 10
for epoch in range(epochs):
    model.train()
    total_loss = 0.0
    for batch in train_loader:
        if batch is None:
            continue
        inputs, targets = batch
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        preds = model(inputs)
        loss = criterion(preds, targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    avg_loss = total_loss / len(train_loader) if len(train_loader) > 0 else 0
    print(f"Epoch {epoch+1}/{epochs}, Loss = {avg_loss:.4f}")

##############################################
# Out:
# Determined input dimension: 516
# Epoch 1/10, Loss = 0.0071
# Epoch 2/10, Loss = 0.0051
# Epoch 3/10, Loss = 0.0041
# Epoch 4/10, Loss = 0.0029
# Epoch 5/10, Loss = 0.0022
# Epoch 6/10, Loss = 0.0013
# Epoch 7/10, Loss = 0.0011
# Epoch 8/10, Loss = 0.0010
# Epoch 9/10, Loss = 0.0010
# Epoch 10/10, Loss = 0.0010

# %%
##############################################
# 10) Evaluation (IoU + mAP@0.5)
##############################################
def box_iou(b1, b2, eps=1e-9):
    x1, y1, w1, h1 = b1
    x2, y2, w2, h2 = b2
    b1_xmin = x1 - w1/2
    b1_xmax = x1 + w1/2
    b1_ymin = y1 - h1/2
    b1_ymax = y1 + h1/2
    b2_xmin = x2 - w2/2
    b2_xmax = x2 + w2/2
    b2_ymin = y2 - h2/2
    b2_ymax = y2 + h2/2
    inter_xmin = max(b1_xmin, b2_xmin)
    inter_ymin = max(b1_ymin, b2_ymin)
    inter_xmax = min(b1_xmax, b2_xmax)
    inter_ymax = min(b1_ymax, b2_ymax)
    inter_w = max(0.0, inter_xmax - inter_xmin)
    inter_h = max(0.0, inter_ymax - inter_ymin)
    inter_area = inter_w * inter_h
    area1 = (b1_xmax - b1_xmin) * (b1_ymax - b1_ymin)
    area2 = (b2_xmax - b2_xmin) * (b2_ymax - b2_ymin)
    union = area1 + area2 - inter_area + eps
    return inter_area / union

def evaluate_bboxes(model, dataloader, iou_threshold=0.5, device="cuda"):
    model.eval()
    iou_list = []
    correct = 0
    total = 0
    with torch.no_grad():
        for batch in dataloader:
            if batch is None:
                continue
            inputs, targets = batch
            inputs, targets = inputs.to(device), targets.to(device)
            preds = model(inputs)
            preds = preds.cpu().numpy()
            targs = targets.cpu().numpy()
            for p, t in zip(preds, targs):
                iou_val = box_iou(p, t)
                iou_list.append(iou_val)
                if iou_val >= iou_threshold:
                    correct += 1
                total += 1
    mean_iou = float(np.mean(iou_list)) if len(iou_list) > 0 else 0.0
    accuracy = correct / total if total > 0 else 0.0
    map_50 = accuracy
    return mean_iou, accuracy, map_50

mean_iou, accuracy, map_50 = evaluate_bboxes(model, test_loader, iou_threshold=0.5, device=device)
print(f"Mean IoU: {mean_iou:.3f}")
print(f"Accuracy (IoU>=0.5): {accuracy:.3f}")
print(f"mAP@0.5 (single-box approximation): {map_50:.3f}")
# Out:
# Mean IoU: 0.631
# Accuracy (IoU>=0.5): 0.859
# mAP@0.5 (single-box approximation): 0.859

# %%
##############################################
# 11) Visualization of Ascending Aorta Bounding Boxes on Test Samples
##############################################
def draw_bbox_cv2(image, bbox, color, thickness=2, normalized=True):
    """
    Draws a rectangle on an OpenCV image given a YOLO-format bbox [x_center, y_center, w, h].
    If normalized=True, scales the coordinates by the image dimensions.
    """
    h, w = image.shape[:2]
    cx, cy, bw, bh = bbox
    if normalized:
        cx *= w
        cy *= h
        bw *= w
        bh *= h
    x1 = int(cx - bw/2)
    y1 = int(cy - bh/2)
    x2 = int(cx + bw/2)
    y2 = int(cy + bh/2)
    cv2.rectangle(image, (x1, y1), (x2, y2), color, thickness)

def visualize_predictions_in_folder(model, backbone, neck,
                                     image_folder,
                                     sov_label_folder,
                                     aorta_label_folder=None,
                                     transform=None,
                                     device="cuda",
                                     save_folder="visualizations",
                                     show_result=False):
    if save_folder is not None:
        os.makedirs(save_folder, exist_ok=True)
    image_files = [f for f in os.listdir(image_folder)
                   if f.lower().endswith((".jpg", ".png", ".jpeg"))]
    for img_name in image_files:
        img_path = os.path.join(image_folder, img_name)
        pil_img = Image.open(img_path).convert("RGB")
        if transform is None:
            transform = T.Compose([T.Resize((640,640)), T.ToTensor()])
        img_tensor = transform(pil_img).unsqueeze(0).to(device)
        
        # Extract features from the image
        backbone_outputs = backbone(img_tensor)
        neck_outputs = neck(backbone_outputs)
        if isinstance(neck_outputs, list):
            feats = neck_outputs[0]
        else:
            feats = neck_outputs
        # Global average pooling to get [1,32]
        feats = F.adaptive_avg_pool2d(feats, (4,4))
        feats = feats.view(feats.size(0), -1).squeeze(0)  # shape [32]
        
        # Load SOV label for this image
        base_name, _ = os.path.splitext(img_name)
        sov_txt = os.path.join(sov_label_folder, base_name + ".txt")
        if not os.path.exists(sov_txt):
            print(f"SOV label not found for {img_name}")
            continue
        with open(sov_txt, "r") as f:
            line = f.readline().strip()
            if not line.strip():  # If the line is empty, skip it
                print(f"Skipping empty line in {sov_txt}")
                continue
            if not all(part.replace('.', '', 1).isdigit() for part in line.split()):
                print(f"Skipping invalid line in {sov_txt}: {line.strip()}")
                continue
            vals = list(map(float, line.split()))
            sov_bbox = vals[1:]  # skip class


        sov_bbox = torch.tensor(sov_bbox, dtype=torch.float32, device=device)
        
        # Create combined input: features [32] + sov_bbox [4] = [36]
        combined_input = torch.cat([feats, sov_bbox], dim=0).unsqueeze(0)
        model.eval()
        with torch.no_grad():
            pred_bbox = model(combined_input)
        pred_bbox = pred_bbox.squeeze(0).cpu().numpy()  # [4]
        
        # Optionally load ground truth aorta bounding box if available
        gt_bbox = None
        if aorta_label_folder is not None:
            aorta_txt = os.path.join(aorta_label_folder, base_name + ".txt")
            if os.path.exists(aorta_txt):
                with open(aorta_txt, "r") as f:
                    line = f.readline().strip()
                    vals = list(map(float, line.split()))
                    gt_bbox = np.array(vals[1:])  # skip class
        
        # Convert PIL image to OpenCV image (BGR)
        image_cv = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
        # Draw predicted bounding box in red
        draw_bbox_cv2(image_cv, pred_bbox, color=(0,0,255), thickness=2, normalized=True)
        # Draw ground truth bounding box in green if available
        # if gt_bbox is not None:
        #     draw_bbox_cv2(image_cv, gt_bbox, color=(0,255,0), thickness=2, normalized=True)
        
        if save_folder is not None:
            out_path = os.path.join(save_folder, base_name + "_vis.png")
            cv2.imwrite(out_path, image_cv)
            print(f"Saved visualization to {out_path}")
        if show_result:
            cv2.imshow("Prediction", image_cv)
            cv2.waitKey(0)
    if show_result:
        cv2.destroyAllWindows()
model=
# Visualize predictions on test samples
visualize_predictions_in_folder(
    model=model,
    backbone=backbone,
    neck=neck,
    image_folder=test_image_folder,
    sov_label_folder="/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV",
    aorta_label_folder="/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelAscendingAorta",
    transform=T.Compose([T.Resize((640,640)), T.ToTensor()]),
    device=device,
    save_folder="acending_aorta_output_visual",
    show_result=False
)
# Out:
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_242_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_242_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_245_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_245_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_242_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_245_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_245_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_245_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_264_vis.png
# Saved visualization to acending_aorta_output_visual/V J - 3mensio Screen Recording_longitudinal_view_702_vis.png
# Saved visualization to acending_aorta_output_visual/V J - 3mensio Screen Recording_longitudinal_view_710_vis.png
# Saved visualization to acending_aorta_output_visual/V K - 3mensio Screen Recording_longitudinal_view_594_vis.png
# Saved visualization to acending_aorta_output_visual/V K - 3mensio Screen Recording_longitudinal_view_723_vis.png
# Saved visualization to acending_aorta_output_visual/V K - 3mensio Screen Recording_longitudinal_view_752_vis.png
# Saved visualization to acending_aorta_output_visual/V V - 3mensio Screen Recording_longitudinal_view_658_vis.png
# Saved visualization to acending_aorta_output_visual/V V - 3mensio Screen Recording_longitudinal_view_763_vis.png
# Saved visualization to acending_aorta_output_visual/V V - 3mensio Screen Recording_longitudinal_view_935_vis.png
# Saved visualization to acending_aorta_output_visual/Varga, Nándor - 3mensio Screen Recording_longitudinal_view_538_vis.png
# Saved visualization to acending_aorta_output_visual/Varga, Nándor - 3mensio Screen Recording_longitudinal_view_688_vis.png
# Saved visualization to acending_aorta_output_visual/Varga, Nándor - 3mensio Screen Recording_longitudinal_view_783_vis.png
# Saved visualization to acending_aorta_output_visual/W D - 3mensio Screen Recording_longitudinal_view_1109_vis.png
# Saved visualization to acending_aorta_output_visual/W D - 3mensio Screen Recording_longitudinal_view_1227_vis.png
# Saved visualization to acending_aorta_output_visual/W D - 3mensio Screen Recording_longitudinal_view_799_vis.png
# Saved visualization to acending_aorta_output_visual/ФИЛИППОВ, Ярослав Владимирович_longitudinal_view_417_vis.png
# Saved visualization to acending_aorta_output_visual/ФИЛИППОВ, Ярослав Владимирович_longitudinal_view_456_vis.png
# Saved visualization to acending_aorta_output_visual/ФИЛИППОВ, Ярослав Владимирович_longitudinal_view_471_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_160_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_160_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_264_blur_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547_blur_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614_blur_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309_vis.png
# Saved visualization to acending_aorta_output_visual/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309_scaling_vis.png
# Skipping invalid line in /mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_314.txt: No SOV detected
# Saved visualization to acending_aorta_output_visual/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_377_vis.png
# Saved visualization to acending_aorta_output_visual/S B - 3mensio Screen Recording_longitudinal_view_1003_vis.png
# Saved visualization to acending_aorta_output_visual/S B - 3mensio Screen Recording_longitudinal_view_845_vis.png
# Saved visualization to acending_aorta_output_visual/S B - 3mensio Screen Recording_longitudinal_view_941_vis.png
# Saved visualization to acending_aorta_output_visual/S G_longitudinal_view_315_vis.png
# Saved visualization to acending_aorta_output_visual/S G_longitudinal_view_325_vis.png
# Saved visualization to acending_aorta_output_visual/S R M R - 3mensio Screen Recording_longitudinal_view_327_vis.png
# Saved visualization to acending_aorta_output_visual/S R M R - 3mensio Screen Recording_longitudinal_view_419_vis.png
# Saved visualization to acending_aorta_output_visual/S R M R - 3mensio Screen Recording_longitudinal_view_473_vis.png
# Saved visualization to acending_aorta_output_visual/S S_longitudinal_view_536_vis.png
# Saved visualization to acending_aorta_output_visual/S S_longitudinal_view_781_vis.png
# Saved visualization to acending_aorta_output_visual/S S_longitudinal_view_900_vis.png
# Saved visualization to acending_aorta_output_visual/S0319RS_longitudinal_view_408_vis.png
# Saved visualization to acending_aorta_output_visual/S0319RS_longitudinal_view_475_vis.png
# Saved visualization to acending_aorta_output_visual/S0319RS_longitudinal_view_482_vis.png
# Saved visualization to acending_aorta_output_visual/S0330KS_longitudinal_view_255_vis.png
# Saved visualization to acending_aorta_output_visual/S0330KS_longitudinal_view_284_vis.png
# Saved visualization to acending_aorta_output_visual/S0330KS_longitudinal_view_331_vis.png
# Saved visualization to acending_aorta_output_visual/Schuszter, József - 3mensio Screen Recording_longitudinal_view_334_vis.png
# Saved visualization to acending_aorta_output_visual/Schuszter, József - 3mensio Screen Recording_longitudinal_view_338_vis.png
# Saved visualization to acending_aorta_output_visual/Schuszter, József - 3mensio Screen Recording_longitudinal_view_449_vis.png
# Saved visualization to acending_aorta_output_visual/TRAJKOVIÆ, MIRJANA - 3mensio Screen Recording_longitudinal_view_432_vis.png
# Saved visualization to acending_aorta_output_visual/TRAJKOVIÆ, MIRJANA - 3mensio Screen Recording_longitudinal_view_561_vis.png
# Saved visualization to acending_aorta_output_visual/TRAJKOVIÆ, MIRJANA - 3mensio Screen Recording_longitudinal_view_608_vis.png
# Saved visualization to acending_aorta_output_visual/Tsintsadze Izolda - 3mensio Screen Recording_longitudinal_view_419_vis.png
# Saved visualization to acending_aorta_output_visual/Tsintsadze Izolda - 3mensio Screen Recording_longitudinal_view_427_vis.png
# Saved visualization to acending_aorta_output_visual/Tsintsadze Izolda - 3mensio Screen Recording_longitudinal_view_429_vis.png
# Saved visualization to acending_aorta_output_visual/U M_longitudinal_view_447_vis.png
# Saved visualization to acending_aorta_output_visual/U M_longitudinal_view_489_vis.png
# Saved visualization to acending_aorta_output_visual/U M_longitudinal_view_504_vis.png
# Saved visualization to acending_aorta_output_visual/U S J - 3mensio Screen Recording_longitudinal_view_753_vis.png
# Saved visualization to acending_aorta_output_visual/U S J - 3mensio Screen Recording_longitudinal_view_825_vis.png
# Saved visualization to acending_aorta_output_visual/U S J - 3mensio Screen Recording_longitudinal_view_845_vis.png
# Saved visualization to acending_aorta_output_visual/V - 3mensio Screen Recording_longitudinal_view_1080_vis.png
# Saved visualization to acending_aorta_output_visual/V - 3mensio Screen Recording_longitudinal_view_747_vis.png
# Saved visualization to acending_aorta_output_visual/V - 3mensio Screen Recording_longitudinal_view_894_vis.png
# Skipping invalid line in /mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV/V A F_longitudinal_view_363.txt: No SOV detected
# Saved visualization to acending_aorta_output_visual/V A F_longitudinal_view_409_vis.png
# Saved visualization to acending_aorta_output_visual/V A F_longitudinal_view_531_vis.png
# Saved visualization to acending_aorta_output_visual/V J - 3mensio Screen Recording_longitudinal_view_582_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_264_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_160_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_177_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_177_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_177_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_177_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_177_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_192_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_192_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_192_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_192_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_192_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_212_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_212_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_212_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_212_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_212_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_259_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_259_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_259_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_259_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_259_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_289_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_289_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_289_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_289_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R M- 3mensio Screen Recording_longitudinal_view_289_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_407_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_407_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_407_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_407_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_407_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_160_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_474_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_474_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_474_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_474_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_474_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_526_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_526_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_526_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_526_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R R S - 3mensio Screen Recording_longitudinal_view_526_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_blur_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547_vis.png
# Saved visualization to acending_aorta_output_visual/S G_longitudinal_view_310_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_264_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395_blur_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_832_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_832_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_832_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_832_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_832_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_877_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_877_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_877_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_877_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_877_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_956_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_956_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_956_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_289_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_289_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_289_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_289_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_358_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_358_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_956_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_358_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_358_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_358_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_396_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_396_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_396_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_396_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_396_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_632_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_632_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_632_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_632_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_632_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_781_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_781_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_781_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_781_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_781_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_858_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_858_blur_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_858_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_858_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/R C - 3mensio Screen Recording_longitudinal_view_956_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R C F_longitudinal_view_289_vis.png
# Saved visualization to acending_aorta_output_visual/R G - 3mensio Screen Recording_longitudinal_view_858_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/R K - 3mensio Screen Recording_longitudinal_view_160_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P G - 3mensio Screen Recording_longitudinal_view_264_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_514_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_514_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_514_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_514_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_514_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_524_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_524_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_524_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_524_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_524_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_550_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_550_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_550_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_550_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P G E_longitudinal_view_550_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_490_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_490_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_490_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_490_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_490_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_576_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_576_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_576_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_576_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_620_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_576_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_620_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_620_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_620_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P K - 3mensio Screen Recording_longitudinal_view_620_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_546_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_546_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_546_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_546_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_546_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_562_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_562_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_562_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_562_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_562_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_576_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_576_blur_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_576_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_576_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/P T - 3mensio Screen Recordin_longitudinal_view_576_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295_blur_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295_brightness_contrast_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295_clahe_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295_scaling_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367_blur_vis.png
# Saved visualization to acending_aorta_output_visual/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367_brightness_contrast_vis.png

# %%
def save_predicted_bboxes_to_txt(model, backbone, neck, image_folder, sov_label_folder, output_folder, transform=None, device="cuda"):
    """
    Predict ascending aorta bounding boxes and save them as .txt files in the specified output folder.
    
    Args:
        model (nn.Module): The trained model to predict bounding boxes.
        backbone (nn.Module): Backbone of YOLOv8.
        neck (nn.Module): Neck of YOLOv8.
        image_folder (str): Path to the folder containing input images.
        sov_label_folder (str): Path to the folder containing SOV labels.
        output_folder (str): Path to save predicted bounding boxes in .txt format.
        transform (callable, optional): Transformations applied to input images.
        device (str): Device to run the model on.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder, exist_ok=True)
    
    image_files = [f for f in os.listdir(image_folder) if f.lower().endswith((".jpg", ".png", ".jpeg"))]
    for img_name in image_files:
        img_path = os.path.join(image_folder, img_name)
        pil_img = Image.open(img_path).convert("RGB")
        if transform is None:
            transform = T.Compose([T.Resize((640, 640)), T.ToTensor()])
        img_tensor = transform(pil_img).unsqueeze(0).to(device)

        # Extract features from the image
        backbone_outputs = backbone(img_tensor)
        neck_outputs = neck(backbone_outputs)
        feats = neck_outputs[0] if isinstance(neck_outputs, list) else neck_outputs
        feats = F.adaptive_avg_pool2d(feats, (4, 4)).view(feats.size(0), -1).squeeze(0)

        # Load SOV label for this image
        base_name, _ = os.path.splitext(img_name)
        sov_txt = os.path.join(sov_label_folder, base_name + ".txt")
        if not os.path.exists(sov_txt):
            print(f"SOV label not found for {img_name}")
            continue
        
        with open(sov_txt, "r") as f:
            line = f.readline().strip()
            if not line.strip():  # If the line is empty, skip it
                print(f"Skipping empty line in {sov_txt}")
                continue
            
            # Check if all parts of the line can be converted to float
            if not all(part.replace('.', '', 1).isdigit() for part in line.split()):
                print(f"Skipping invalid line in {sov_txt}: {line.strip()}")
                continue
            
            # If the line passes the checks, parse it into floats
            vals = list(map(float, line.split()))
            sov_bbox = vals[1:]  # skip class
            sov_bbox = torch.tensor(sov_bbox, dtype=torch.float32, device=device)
        
        sov_bbox = torch.tensor(sov_bbox, dtype=torch.float32, device=device)

        # Combine features and SOV bounding box
        combined_input = torch.cat([feats, sov_bbox], dim=0).unsqueeze(0)

        # Predict ascending aorta bounding box
        model.eval()
        with torch.no_grad():
            pred_bbox = model(combined_input).squeeze(0).cpu().numpy()  # [4]

        # Save the predicted bounding box to a .txt file
        output_txt_path = os.path.join(output_folder, base_name + ".txt")
        with open(output_txt_path, "w") as txt_file:
            txt_file.write(f"0 {pred_bbox[0]:.6f} {pred_bbox[1]:.6f} {pred_bbox[2]:.6f} {pred_bbox[3]:.6f}\n")
        
        print(f"Saved predicted bbox to {output_txt_path}")
    
# Visualize predictions on test samples
save_predicted_bboxes_to_txt(
    model=model,
    backbone=backbone,
    neck=neck,
    image_folder="/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/totalImages",
    sov_label_folder="/mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV",
    output_folder="AOTBB",
    
)
# Out:
# /tmp/ipykernel_2048424/1401593929.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sov_bbox = torch.tensor(sov_bbox, dtype=torch.float32, device=device)
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_471.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_471_blur.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_471_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_471_clahe.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_471_scaling.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_474.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_474_blur.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_474_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_474_clahe.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_474_scaling.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_480.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_480_blur.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_480_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_480_clahe.txt
# Saved predicted bbox to AOTBB/A A - 3mensio Screen Recording_longitudinal_view_480_scaling.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_361.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_361_blur.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_361_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_361_clahe.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_361_scaling.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_423.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_423_blur.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_423_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_423_clahe.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_423_scaling.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_432.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_432_blur.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_432_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_432_clahe.txt
# Saved predicted bbox to AOTBB/A A 2 - 3mensio Screen Recording_longitudinal_view_432_scaling.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_341.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_341_blur.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_341_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_341_clahe.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_341_scaling.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_359.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_359_blur.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_359_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_359_clahe.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_359_scaling.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_584.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_584_blur.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_584_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_584_clahe.txt
# Saved predicted bbox to AOTBB/A A 3 - 3mensio Screen Recording_longitudinal_view_584_scaling.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_184.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_184_blur.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_184_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_184_clahe.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_184_scaling.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_188.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_188_blur.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_188_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_188_clahe.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_188_scaling.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_75.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_75_blur.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_75_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_75_clahe.txt
# Saved predicted bbox to AOTBB/A H - 3mensio Screen Recording_longitudinal_view_75_scaling.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_189.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_189_blur.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_189_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_189_clahe.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_189_scaling.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_231.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_231_blur.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_231_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_231_clahe.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_231_scaling.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_300.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_300_blur.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_300_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_300_clahe.txt
# Saved predicted bbox to AOTBB/A J - 3mensio Screen Recording_longitudinal_view_300_scaling.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_249.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_249_blur.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_249_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_249_clahe.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_249_scaling.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_282.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_282_blur.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_282_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_282_clahe.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_282_scaling.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_332.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_332_blur.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_332_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_332_clahe.txt
# Saved predicted bbox to AOTBB/A K H - 3mensio Screen Recording_longitudinal_view_332_scaling.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_422.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_422_blur.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_422_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_422_clahe.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_422_scaling.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_438.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_438_blur.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_438_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_438_clahe.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_438_scaling.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_457.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_457_blur.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_457_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_457_clahe.txt
# Saved predicted bbox to AOTBB/A M - 3mensio Screen Recording_longitudinal_view_457_scaling.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_377.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_377_blur.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_377_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_377_clahe.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_377_scaling.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_381.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_381_blur.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_381_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_381_clahe.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_381_scaling.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_431.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_431_blur.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_431_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_431_clahe.txt
# Saved predicted bbox to AOTBB/A M R - 3mensio Screen Recording_longitudinal_view_431_scaling.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_298.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_298_blur.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_298_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_322_blur.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_322_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_322_clahe.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_322_scaling.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_327.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_327_blur.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_327_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_327_clahe.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_327_scaling.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361.txt
# Skipping invalid line in /mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361_blur.txt: No SOV detected
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361_brightness_contrast.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361_clahe.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_298_clahe.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361_scaling.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370_blur.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370_brightness_contrast.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370_clahe.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370_scaling.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376_blur.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376_brightness_contrast.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376_clahe.txt
# Saved predicted bbox to AOTBB/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376_scaling.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_100.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_100_blur.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_100_brightness_contrast.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_100_clahe.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_100_scaling.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_114.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_114_blur.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_114_brightness_contrast.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_114_clahe.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_114_scaling.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_120.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_120_blur.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_120_brightness_contrast.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_120_clahe.txt
# Saved predicted bbox to AOTBB/Anonymous_longitudinal_view_120_scaling.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_288.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_288_blur.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_288_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_288_clahe.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_288_scaling.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_294.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_294_blur.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_294_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_294_clahe.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_294_scaling.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_298.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_298_blur.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_298_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_298_clahe.txt
# Saved predicted bbox to AOTBB/B D - 3mensio Screen Recording_longitudinal_view_298_scaling.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_360.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_360_blur.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_360_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_360_clahe.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_360_scaling.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_368.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_368_blur.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_368_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_368_clahe.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_368_scaling.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_398.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_398_blur.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_398_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_398_clahe.txt
# Saved predicted bbox to AOTBB/B E - 3mensio Screen Recording_longitudinal_view_398_scaling.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_108.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_108_blur.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_108_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_108_clahe.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_108_scaling.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_136.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_136_blur.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_136_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_136_clahe.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_136_scaling.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_67.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_67_blur.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_67_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_67_clahe.txt
# Saved predicted bbox to AOTBB/B G - 3mensio Screen Recording_longitudinal_view_67_scaling.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_130.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_130_blur.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_130_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_130_clahe.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_130_scaling.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_136.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_136_blur.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_136_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_136_clahe.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_136_scaling.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_63.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_63_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_63_clahe.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_63_scaling.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_183.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_183_blur.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_183_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_298_scaling.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_183_clahe.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_183_scaling.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_194.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_194_blur.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_194_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_194_clahe.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_194_scaling.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_198.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_198_blur.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_198_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_198_clahe.txt
# Saved predicted bbox to AOTBB/B L I_longitudinal_view_198_scaling.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_104.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_104_blur.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_104_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_104_clahe.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_104_scaling.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_150.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_150_blur.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_150_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_150_clahe.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_150_scaling.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_97.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_97_blur.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_97_brightness_contrast.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_97_clahe.txt
# Saved predicted bbox to AOTBB/B S N N - 3mensio Screen Recording_longitudinal_view_97_scaling.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_104.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_104_blur.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_104_brightness_contrast.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_104_clahe.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_104_scaling.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_118.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_118_blur.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_118_brightness_contrast.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_118_clahe.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_118_scaling.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_129.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_129_blur.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_129_brightness_contrast.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_129_clahe.txt
# Saved predicted bbox to AOTBB/BATISTA CARDENAS, JORGE EVERGITO - 3mensio Screen Recording_longitudinal_view_129_scaling.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_357.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_357_blur.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_357_brightness_contrast.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_357_clahe.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_357_scaling.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_367.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_367_blur.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_367_brightness_contrast.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_367_clahe.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_367_scaling.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_378.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_378_blur.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_378_brightness_contrast.txt
# Saved predicted bbox to AOTBB/A T M F - 3mensio Screen Recording_longitudinal_view_322.txt
# Saved predicted bbox to AOTBB/B K A - 3mensio Screen Recording_longitudinal_view_63_blur.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_378_clahe.txt
# Saved predicted bbox to AOTBB/C F - 3mensio Screen Recording_longitudinal_view_378_scaling.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_256_blur.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_256.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_256_brightness_contrast.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_256_clahe.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_256_scaling.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_303.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_303_blur.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_303_brightness_contrast.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_303_clahe.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_303_scaling.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_330.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_330_blur.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_330_brightness_contrast.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_330_clahe.txt
# Saved predicted bbox to AOTBB/C J P - 3mensio Screen Recording_longitudinal_view_330_scaling.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_195.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_195_blur.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_195_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_195_clahe.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_195_scaling.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_205.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_205_blur.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_205_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_205_clahe.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_205_scaling.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_211.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_211_blur.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_211_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_211_clahe.txt
# Saved predicted bbox to AOTBB/D A - 3mensio Screen Recording_longitudinal_view_211_scaling.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_155.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_155_blur.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_155_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_155_clahe.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_155_scaling.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_159.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_159_blur.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_159_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_159_clahe.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_159_scaling.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_163.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_163_blur.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_163_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_163_clahe.txt
# Saved predicted bbox to AOTBB/D C S M B- 3mensio Screen Recording_longitudinal_view_163_scaling.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_359.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_359_blur.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_359_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_359_clahe.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_359_scaling.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_367.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_367_blur.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_367_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_367_clahe.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_367_scaling.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_380.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_380_blur.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_380_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_380_clahe.txt
# Saved predicted bbox to AOTBB/D J - 3mensio Screen Recording_longitudinal_view_380_scaling.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_149.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_149_blur.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_149_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_149_clahe.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_149_scaling.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_180.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_180_blur.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_180_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_180_clahe.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_180_scaling.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_184.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_184_blur.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_184_brightness_contrast.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_184_clahe.txt
# Saved predicted bbox to AOTBB/D J 2- 3mensio Screen Recording_longitudinal_view_184_scaling.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_121.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_121_scaling.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_121_blur.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_121_brightness_contrast.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_121_clahe.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_125.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_125_blur.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_125_brightness_contrast.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_125_clahe.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_89_brightness_contrast.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_89_clahe.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_89_scaling.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_332.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_332_blur.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_332_brightness_contrast.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_332_clahe.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_332_scaling.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_335.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_335_blur.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_335_brightness_contrast.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_335_clahe.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_335_scaling.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_342.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_342_brightness_contrast.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_125_scaling.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_342_blur.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_342_clahe.txt
# Saved predicted bbox to AOTBB/F S - 3mensio Screen Recording_longitudinal_view_342_scaling.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_114.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_114_blur.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_114_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_114_clahe.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_114_scaling.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_115.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_115_blur.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_115_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_115_clahe.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_115_scaling.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_116.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_76.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_76_blur.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_76_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_76_clahe.txt
# Saved predicted bbox to AOTBB/G G - 3mensio Screen Recording_longitudinal_view_76_scaling.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_116_blur.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_116_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_116_clahe.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_116_scaling.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_117.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_117_blur.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_117_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_117_clahe.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_117_scaling.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_120.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_120_blur.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_120_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_120_clahe.txt
# Saved predicted bbox to AOTBB/G G R_longitudinal_view_120_scaling.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_316.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_316_blur.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_316_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_316_clahe.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_316_scaling.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_318.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_318_blur.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_318_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_318_clahe.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_318_scaling.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_320.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_320_blur.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_320_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_320_clahe.txt
# Saved predicted bbox to AOTBB/G K - 3mensio Screen Recording_longitudinal_view_320_scaling.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_456.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_456_blur.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_456_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_456_clahe.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_456_scaling.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_457.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_457_blur.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_457_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_457_clahe.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_457_scaling.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_458.txt
# Skipping invalid line in /mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV/G S F - 3mensio Screen Recording_longitudinal_view_458_blur.txt: No SOV detected
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_458_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_458_clahe.txt
# Saved predicted bbox to AOTBB/G S F - 3mensio Screen Recording_longitudinal_view_458_scaling.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_375.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_375_blur.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_375_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_375_clahe.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_375_scaling.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_376.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_376_blur.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_376_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_376_clahe.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_376_scaling.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_89.txt
# Saved predicted bbox to AOTBB/E J D - 3mensio Screen Recording_longitudinal_view_89_blur.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_377.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_377_scaling.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_377_blur.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_377_brightness_contrast.txt
# Saved predicted bbox to AOTBB/G S R C S- 3mensio Screen Recording_longitudinal_view_377_clahe.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_148.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_148_blur.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_148_brightness_contrast.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_148_clahe.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_148_scaling.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_197.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_197_blur.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_197_brightness_contrast.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_197_clahe.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_197_scaling.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_224.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_224_blur.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_224_brightness_contrast.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_224_clahe.txt
# Saved predicted bbox to AOTBB/Gurmukh  Singh - 3mensio Screen Recording_longitudinal_view_224_scaling.txt
# Saved predicted bbox to AOTBB/Gábriel, Jánosné,, Dr - 3mensio Screen Recording_longitudinal_view_124.txt
# Saved predicted bbox to AOTBB/Gábriel, Jánosné,, Dr - 3mensio Screen Recording_longitudinal_view_124_blur.txt
# Saved predicted bbox to AOTBB/Gábriel, Jánosné,, Dr - 3mensio Screen Recording_longitudinal_view_124_brightness_contrast.txt
# Saved predicted bbox to AOTBB/Gábriel, Jánosné,, Dr - 3mensio Screen Recording_longitudinal_view_124_clahe.txt
# Saved predicted bbox to AOTBB/Gábriel, Jánosné,, Dr - 3mensio Screen Recording_longitudinal_view_124_scaling.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_233.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_233_blur.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_233_brightness_contrast.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_233_clahe.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_233_scaling.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_267.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_267_blur.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_267_brightness_contrast.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_267_clahe.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_267_scaling.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_293.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_293_blur.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_293_brightness_contrast.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_293_clahe.txt
# Saved predicted bbox to AOTBB/H A V_longitudinal_view_293_scaling.txt
# Saved predicted bbox to AOTBB/H F S - 3mensio Screen Recording_longitudinal_view_132.txt
# Saved predicted bbox to AOTBB/H F S - 3mensio Screen Recording_longitudinal_view_132_blur.txt
# ...
# Saved predicted bbox to AOTBB/TRAJKOVIÆ, MIRJANA - 3mensio Screen Recording_longitudinal_view_608.txt
# Saved predicted bbox to AOTBB/Tsintsadze Izolda - 3mensio Screen Recording_longitudinal_view_419.txt
# Saved predicted bbox to AOTBB/Tsintsadze Izolda - 3mensio Screen Recording_longitudinal_view_427.txt
# Saved predicted bbox to AOTBB/Tsintsadze Izolda - 3mensio Screen Recording_longitudinal_view_429.txt
# Saved predicted bbox to AOTBB/U M_longitudinal_view_447.txt
# Saved predicted bbox to AOTBB/U M_longitudinal_view_489.txt
# Saved predicted bbox to AOTBB/U M_longitudinal_view_504.txt
# Saved predicted bbox to AOTBB/U S J - 3mensio Screen Recording_longitudinal_view_753.txt
# Saved predicted bbox to AOTBB/U S J - 3mensio Screen Recording_longitudinal_view_825.txt
# Saved predicted bbox to AOTBB/U S J - 3mensio Screen Recording_longitudinal_view_845.txt
# Saved predicted bbox to AOTBB/V - 3mensio Screen Recording_longitudinal_view_1080.txt
# Saved predicted bbox to AOTBB/V - 3mensio Screen Recording_longitudinal_view_747.txt
# Saved predicted bbox to AOTBB/V - 3mensio Screen Recording_longitudinal_view_894.txt
# Skipping invalid line in /mnt/nvme_disk2/User_data/hp927k/phase2/AscendingAortaBBprediction/labelSOV/V A F_longitudinal_view_363.txt: No SOV detected
# Saved predicted bbox to AOTBB/V A F_longitudinal_view_409.txt
# Saved predicted bbox to AOTBB/V A F_longitudinal_view_531.txt
# Saved predicted bbox to AOTBB/V J - 3mensio Screen Recording_longitudinal_view_582.txt
# Saved predicted bbox to AOTBB/P G - 3mensio Screen Recording_longitudinal_view_264_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_160_scaling.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_177.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_177_blur.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_177_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_177_clahe.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_177_scaling.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_192.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_192_blur.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_192_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_192_clahe.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_192_scaling.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_212.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_212_blur.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_212_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_212_clahe.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_212_scaling.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_259.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_259_blur.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_259_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_259_clahe.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_259_scaling.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_289.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_289_blur.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_289_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_289_clahe.txt
# Saved predicted bbox to AOTBB/R M- 3mensio Screen Recording_longitudinal_view_289_scaling.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_407.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_407_blur.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_407_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_407_clahe.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_407_scaling.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_160.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_474.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_474_blur.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_474_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_474_clahe.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_474_scaling.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_526.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_526_blur.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_526_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_526_clahe.txt
# Saved predicted bbox to AOTBB/R R S - 3mensio Screen Recording_longitudinal_view_526_scaling.txt
# Saved predicted bbox to AOTBB/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459.txt
# Saved predicted bbox to AOTBB/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_blur.txt
# Saved predicted bbox to AOTBB/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_brightness_contrast.txt
# Saved predicted bbox to AOTBB/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_clahe.txt
# Saved predicted bbox to AOTBB/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_scaling.txt
# Saved predicted bbox to AOTBB/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547.txt
# Saved predicted bbox to AOTBB/S G_longitudinal_view_310.txt
# Saved predicted bbox to AOTBB/P G - 3mensio Screen Recording_longitudinal_view_264_clahe.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367_clahe.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367_scaling.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395_blur.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395_brightness_contrast.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395_clahe.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_395_scaling.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_832.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_832_blur.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_832_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_832_clahe.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_832_scaling.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_877.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_877_blur.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_877_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_877_clahe.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_877_scaling.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_956.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_956_blur.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_956_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_289_blur.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_289_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_289_clahe.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_289_scaling.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_358.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_358_blur.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_956_clahe.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_358_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_358_clahe.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_358_scaling.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_396.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_396_blur.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_396_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_396_clahe.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_396_scaling.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_632.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_632_blur.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_632_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_632_clahe.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_632_scaling.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_781.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_781_blur.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_781_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_781_clahe.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_781_scaling.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_858.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_858_blur.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_858_brightness_contrast.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_858_clahe.txt
# Saved predicted bbox to AOTBB/R C - 3mensio Screen Recording_longitudinal_view_956_scaling.txt
# Saved predicted bbox to AOTBB/R C F_longitudinal_view_289.txt
# Saved predicted bbox to AOTBB/R G - 3mensio Screen Recording_longitudinal_view_858_scaling.txt
# Saved predicted bbox to AOTBB/R K - 3mensio Screen Recording_longitudinal_view_160_clahe.txt
# Saved predicted bbox to AOTBB/P G - 3mensio Screen Recording_longitudinal_view_264_scaling.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_514.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_514_blur.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_514_brightness_contrast.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_514_clahe.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_514_scaling.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_524.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_524_blur.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_524_brightness_contrast.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_524_clahe.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_524_scaling.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_550.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_550_blur.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_550_brightness_contrast.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_550_scaling.txt
# Saved predicted bbox to AOTBB/P G E_longitudinal_view_550_clahe.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_490.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_490_blur.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_490_brightness_contrast.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_490_clahe.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_490_scaling.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_576.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_576_blur.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_576_brightness_contrast.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_576_clahe.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_576_scaling.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_620.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_620_blur.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_620_brightness_contrast.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_620_clahe.txt
# Saved predicted bbox to AOTBB/P K - 3mensio Screen Recording_longitudinal_view_620_scaling.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_546.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_546_blur.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_546_brightness_contrast.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_546_clahe.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_546_scaling.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_562.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_562_blur.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_562_brightness_contrast.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_562_clahe.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_562_scaling.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_576.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_576_blur.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_576_brightness_contrast.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_576_clahe.txt
# Saved predicted bbox to AOTBB/P T - 3mensio Screen Recordin_longitudinal_view_576_scaling.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295_blur.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295_brightness_contrast.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295_clahe.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_295_scaling.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367_blur.txt
# Saved predicted bbox to AOTBB/PANTELIDOU, ZOI - 3mensio Screen Recording_longitudinal_view_367_brightness_contrast.txt

# %%
torch.save(model.state_dict(),"ascending_aorta_model_without_manual_loss.pt")

# %%
###
